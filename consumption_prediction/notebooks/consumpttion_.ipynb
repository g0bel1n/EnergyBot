# %%
import pandas as pd
import numpy as np
from datetime import datetime
import plotly.express as px
import os

os.chdir("C:/Users/idris/Desktop/ENSAE/S1_3A/Cloud_Computing/EnergyBot")
from  consumption_prediction.src.data.conso_ps_profil import consommation

# %%
df_conso = consommation(12, "RES11")
# Out:
#       HORODATE SOUS_PROFIL  CONSOMMATION  PUISSANCE_SOUSCRITE
# 0   2021-01-01       RES11     29.038765                   12
# 1   2021-01-02       RES11     30.677139                   12
# 2   2021-01-03       RES11     30.494401                   12
# 3   2021-01-04       RES11     30.134175                   12
# 4   2021-01-05       RES11     29.823669                   12
# ..         ...         ...           ...                  ...
# 360 2021-12-27       RES11     24.066235                   12
# 361 2021-12-28       RES11     23.107530                   12
# 362 2021-12-29       RES11     21.817256                   12
# 363 2021-12-30       RES11     20.384923                   12
# 364 2021-12-31       RES11     21.975059                   12
#
# [365 rows x 4 columns]

# %%
fig = px.line(df_conso, x='HORODATE', 
              y="CONSOMMATION", color="SOUS_PROFIL", width=950, height=500)
#fig.update_layout(title="Série journalière du coefficient dynamique entre 01 décembre 2021 et le 31 mars")
fig.show()
