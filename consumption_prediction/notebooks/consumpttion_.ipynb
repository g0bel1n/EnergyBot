# %%
import pandas as pd
import numpy as np
from datetime import datetime
import plotly.express as px
import os

os.chdir("C:/Users/idris/Desktop/ENSAE/S1_3A/Cloud_Computing/EnergyBot")
from  consumption_prediction.src.data.conso_ps_profil import consommation_PS_PROFIL, data_coeff_profil, aggregats_consommation

# %%
df_conso = consommation_PS_PROFIL(12, "RES2")
df_conso
# Out:
#       HORODATE SOUS_PROFIL  CONSOMMATION  PUISSANCE_SOUSCRITE
# 0   2021-01-01        RES2     28.782577                   12
# 1   2021-01-02        RES2     30.729357                   12
# 2   2021-01-03        RES2     30.595572                   12
# 3   2021-01-04        RES2     30.686863                   12
# 4   2021-01-05        RES2     30.557003                   12
# ..         ...         ...           ...                  ...
# 360 2021-12-27        RES2     20.091634                   12
# 361 2021-12-28        RES2     19.203085                   12
# 362 2021-12-29        RES2     17.778714                   12
# 363 2021-12-30        RES2     16.242922                   12
# 364 2021-12-31        RES2     17.902027                   12
#
# [365 rows x 4 columns]

# %%
df_conso_agg = aggregats_consommation(12, "RES2")
df_conso_agg
# Out:
#    PUISSANCE_SOUSCRITE SOUS_PROFIL  CONSOMMATION_TOTALE_ANNUELLE  \
# 0                   12        RES2                   5575.278101
#
#    CONSOMMATION_MOYENNE_JOURNALIERE
# 0                         15.274735

# %%
fig = px.line(df_conso, x='HORODATE', y="CONSOMMATION", width=950, height=500)
#fig.update_layout(title="Série journalière du coefficient dynamique entre 01 décembre 2021 et le 31 mars")
fig.show()
